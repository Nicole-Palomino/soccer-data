# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Modelo 15:9

# %% [markdown]
# ## 15:9

# %%
fig = plt.figure(figsize=(15,9),constrained_layout=True)
gs = fig.add_gridspec(nrows=5,ncols=7)
fig.set_facecolor('white')

ax1 = fig.add_subplot(gs[:1, :1])
ax1.set_title('Escudo')
ax2 = fig.add_subplot(gs[:1, 1:2])
ax2.set_title('Escudo') 
ax3 = fig.add_subplot(gs[:1, 2:5])
ax3.set_title('Informacion')
ax4 = fig.add_subplot(gs[:1, 5:6])
ax4.set_title('Escudo')
ax5 = fig.add_subplot(gs[:1, 6:7])
ax5.set_title('Escudo')

ax6 = fig.add_subplot(gs[1:3, :2])
ax6.set_title('Jugador Destacado')
ax7 = fig.add_subplot(gs[1:3, 2:5])
ax7.set_title('Match momentum')
ax8 = fig.add_subplot(gs[1:3, 5:7])
ax8.set_title('Jugador Destacado')

ax9 = fig.add_subplot(gs[3:4, :2])
ax9.set_title('Datos extras')

ax10 = fig.add_subplot(gs[4:5, :2])
ax10.set_title('Mapa de calor')

ax11 = fig.add_subplot(gs[3:5, 2:5])
ax11.set_title('xg Flow Chart')

ax12 = fig.add_subplot(gs[3:4, 5:7])
ax12.set_title('Datos extras')

ax13 = fig.add_subplot(gs[4:5, 5:7])
ax13.set_title('Mapa de calor')
# Out:
# Text(0.5, 1.0, 'Mapa de calor')

# %%
fig = plt.figure(figsize=(15,9),constrained_layout=True)
gs = fig.add_gridspec(nrows=5,ncols=7)
fig.set_facecolor('beige')

# Escudo local
ax1 = fig.add_subplot(gs[:1, :1])

# Informacion del partido
ax2 = fig.add_subplot(gs[:1, 1:6])

# Escudo visitante
ax5 = fig.add_subplot(gs[:1, 6:7])

# Jugador local
ax6 = fig.add_subplot(gs[1:4, :2])

# Estadisticas del partido
ax7 = fig.add_subplot(gs[1:3, 2:5])

# Jugador visitante
ax8 = fig.add_subplot(gs[1:4, 5:7])

# mapa de tiros
ax9 = fig.add_subplot(gs[3:5, 2:5])

# mapa de calor local
ax10 = fig.add_subplot(gs[4:5, :2])

# mapa de calor visita
ax11 = fig.add_subplot(gs[4:5, 5:7])

# %% [markdown]
# # 9:12

# %%
fig = plt.figure(figsize=(9,10),constrained_layout=True)
gs = fig.add_gridspec(nrows=4,ncols=4)
fig.set_facecolor('white')

ax1 = fig.add_subplot(gs[:1, :4])
ax1.set_title('Informacion')

ax2 = fig.add_subplot(gs[1:4, :2])
ax2.set_title('Estadisticas') 

ax4 = fig.add_subplot(gs[1:3, 2:4])
ax4.set_title('Player of the match')

ax8 = fig.add_subplot(gs[3:4, 2:4])
ax8.set_title('Mapa de calor')
# Out:
# Text(0.5, 1.0, 'Mapa de calor')

# %%
fig = plt.figure(figsize=(9,15),constrained_layout=True)
gs = fig.add_gridspec(nrows=6,ncols=4)
fig.set_facecolor('ivory')

# informacion
ax1 = fig.add_subplot(gs[:1, :4])

# mapa de tiros
ax2 = fig.add_subplot(gs[1:3, :2])
ax2.set_title('Mapa de tiros')

ax3 = fig.add_subplot(gs[1:2, 2:4])
ax3.set_title('Match Momentum') 

ax4 = fig.add_subplot(gs[2:3, 2:4])
ax4.set_title('xG Flow Chart') 

ax5 = fig.add_subplot(gs[3:5, 2:4])
ax5.set_title('Player of the match') 

ax6 = fig.add_subplot(gs[5:6, 2:4])
ax6.set_title('Mapa de calor')

ax7 = fig.add_subplot(gs[3:6, :2])
ax7.set_title('Estadisticas')
# Out:
# Text(0.5, 1.0, 'Estadisticas')

# %% [markdown]
# # Player of the match

# %%
fig = plt.figure(figsize=(9,12),constrained_layout=True)
gs = fig.add_gridspec(nrows=4,ncols=3)

ax1 = fig.add_subplot(gs[:1, :1])
ax1.set_title('Imagen jugador')
ax2 = fig.add_subplot(gs[:1, 1:3])
ax2.set_title('Información')

ax3 = fig.add_subplot(gs[1:3, :1])
ax3.set_title('Mapa de calor') 
ax4 = fig.add_subplot(gs[1:2, 1:3])
ax4.set_title('Estadisticas generales')

ax5 = fig.add_subplot(gs[2:3, 1:3])
ax5.set_title('Estadisticas de ofensivas')

ax6 = fig.add_subplot(gs[3:4, 1:3])
ax6.set_title('Estadisticas de defensivas')

ax7 = fig.add_subplot(gs[3:4, :1])
ax7.set_title('Mapa de tiros')
# Out:
# Text(0.5, 1.0, 'Mapa de tiros')

# %% [markdown]
# # Extras

# %%
fig = plt.figure(figsize=(16,9),constrained_layout=True)
gs = fig.add_gridspec(nrows=5,ncols=7)
fig.set_facecolor('white')

ax1 = fig.add_subplot(gs[:1, :1])
ax1.set_title('[:1, :1]')
ax2 = fig.add_subplot(gs[:1, 1:2])
ax2.set_title('[:1, 1:2]') 
ax3 = fig.add_subplot(gs[:1, 2:5])
ax3.set_title('[:1, 2:5]')
ax4 = fig.add_subplot(gs[:1, 5:7])
ax4.set_title('[:1, 5:7]')
ax5 = fig.add_subplot(gs[1:3, :2])
ax5.set_title('[1:3, :2]')
ax6 = fig.add_subplot(gs[1:2, 2:5])
ax6.set_title('[1:2, 2:5]')
ax7 = fig.add_subplot(gs[2:3, 2:5])
ax7.set_title('[2:3, 2:5]')
ax8 = fig.add_subplot(gs[1:3, 5:7])
ax8.set_title('[1:3, 5:7]')
ax9 = fig.add_subplot(gs[3:4, :2])
ax9.set_title('[3:4, :2]')
ax10 = fig.add_subplot(gs[4:5, :2])
ax10.set_title('[4:5, :2]')
ax11 = fig.add_subplot(gs[3:5, 2:5])
ax11.set_title('[3:5, 2:5]')
ax12 = fig.add_subplot(gs[3:4, 5:7])
ax12.set_title('[3:4, 5:7]')
ax13 = fig.add_subplot(gs[4:5, 5:7])
ax13.set_title('[4:5, 5:7]')
# Out:
# Text(0.5, 1.0, '[4:5, 5:7]')
